# %%
import pandas as pd
import random
import uuid

# Function to generate random usernames
def generate_username():
    return 'user_' + ''.join(random.choices('abcdefghijklmnopqrstuvwxyz0123456789', k=8))

# Generate 100 example records
data = {
    'instagram_poster_id': [str(uuid.uuid4()) for _ in range(100)],
    'instagram_post_id': [str(uuid.uuid4()) for _ in range(100)],
    'instagram_commenter_id': [str(uuid.uuid4()) for _ in range(100)],
    'instagram_username': [generate_username() for _ in range(100)],
    'instagram_comment': [
        random.choice([
            # Positive comments
            "This is awesome!", "Great post!", "I completely agree!", "Nice picture!",
            "Love this content!", "Amazing post!", "Thanks for sharing!", "This is really inspiring!",
            "Keep up the great work!", "This made my day!", "Fantastic shot!", "You're so talented!",
            "This is goals!", "Can't stop looking at this!", "Absolutely stunning!",
            "Incredible work!", "You nailed it!", "This is perfection!", "So impressive!",
            "You've outdone yourself!", "This deserves more likes!", "I'm in awe!", "Brilliant content!",
            "This is next level!", "You're killing it!", "Masterpiece!", "I'm blown away!",
            "This is pure gold!", "You're an inspiration!", "Phenomenal post!", "This is everything!",
            "You've got skills!", "I'm obsessed with this!", "Top-notch content!", "This is fire!",
            "You're a genius!", "This deserves an award!", "I'm speechless!", "Absolutely incredible!",
            "You've raised the bar!", "This is art!", "Mind-blowing stuff!",
            
            # Neutral comments
            "Interesting.", "Okay, I see.", "Not bad.", "It's alright.", "Hmm, interesting perspective.",
            "I'm not sure what to think.", "This is different.", "I guess it's cool.", "Meh.",
            "It's a post.", "Just scrolling by.", "I have no strong feelings about this.",
            "Fair enough.", "I suppose.", "Could be worse.", "It exists.", "Noted.",
            "Moving on.", "Whatever works for you.", "If you say so.", "Sure, why not.",
            "I'll think about it.", "Huh.", "That's a thing.", "Okay then.", "I see what you did there.",
            "Well, that happened.", "Interesting choice.", "That's one way to do it.", "I guess that's valid.",
            "Not my thing, but okay.", "To each their own.", "I'm indifferent.", "It's certainly unique.",
            "I'll reserve judgment.", "That's... something.", "I have questions, but I'll keep scrolling.",
            "Not what I expected, but okay.", "I'm processing this.",
            
            # Negative comments
            "I don't get it.", "This is overrated.", "Not my cup of tea.", "I've seen better.",
            "Why would you post this?", "This is disappointing.", "I expected more.",
            "This doesn't make sense.", "I'm not impressed.", "You could do better.",
            "This is a letdown.", "I'm cringing.", "This ain't it.", "Hard pass.",
            "You've done better before.", "This feels forced.", "I'm not feeling it.",
            "This is a miss for me.", "Yikes.", "This is problematic.", "Not your best work.",
            "This feels off.", "I'm confused and not in a good way.", "This is a no from me.",
            "I can't support this.", "This missed the mark.", "I'm actually offended.",
            "This is tone-deaf.", "Did you even try?", "This is embarrassing.",
            "I'm unfollowing after this.", "This is why we can't have nice things.",
            "I regret clicking on this.", "This is a waste of time.", "Do better.",
            "I'm disappointed in you.", "This is just bad.",
            
            # Questions or engagement
            "What's the story behind this?", "Where was this taken?", "How did you do that?",
            "Can you explain more?", "When's your next post?", "Do you have a tutorial for this?",
            "What inspired you?", "How long did this take?", "What equipment did you use?",
            "Can you share your process?", "Is this a series?", "What's your favorite part of this?",
            "Any behind-the-scenes info?", "Who else was involved in this?", "What challenges did you face?",
            "How does this relate to your previous work?", "What's next for you?",
            "Can you recommend similar content?", "How can we support your work?",
            "What's the best way to learn this skill?", "Do you offer classes or workshops?",
            "How do you come up with your ideas?", "What's your creative process like?",
            "Can you share any tips for beginners?", "How has your style evolved over time?",
            "What's the most important lesson you've learned in your field?",
            "How do you stay motivated?", "What's your ultimate goal with your content?",
            "How do you handle criticism?", "What's the best advice you've ever received?",
            "How do you balance creativity and commercial success?",
            
            # Emoji-only responses
            "😍 Love it!", "👍 Nice one", "🔥 Fire", "💯 Spot on", "🙌 Yasss", "😊 Sweet", "🤔 Hmm", "😐 Meh", "😕 Unsure", "👎 Nah",
            "❤️ Adore", "🎉 Congrats", "👏 Bravo", "🤩 Awesome", "😎 Cool", "🥰 Adorable", "😮 Wow", "🤯 Mind blown", "😂 Hilarious", "😍 Gorgeous",
            "💪 Strong work", "👀 Interesting", "🙏 Thanks", "💖 Love this", "🌟 Stellar", "✨ Magic", "💕 Lovely", "🔝 Top notch", "👌 Perfect", "💥 Boom",
            "🚀 Next level", "💡 Brilliant", "🏆 Winner", "🎨 Artistic", "📸 Great shot", "🎭 Dramatic", "🌈 Colorful", "🦄 Unique", "🍾 Cheers", "🥳 Party time",
            
            # Longer, more detailed responses
            "This post really resonates with me. It reminds me of my own experiences.",
            "I'm not sure I agree with the message here, but I appreciate you sharing your perspective.",
            "This content feels a bit repetitive. Maybe try something new next time?",
            "Your growth as a content creator is really evident in this post. Well done!",
            "I'm conflicted about this. On one hand it's visually appealing, but the message is problematic.",
            "I've been following your journey for a while now, and it's incredible to see how far you've come. This post is a testament to your dedication and creativity.",
            "While I understand what you're trying to convey, I think there might be some unintended implications here. Have you considered how this might be interpreted by different audiences?",
            "This post challenges my preconceptions and makes me reconsider my stance on the topic. Thank you for providing such thought-provoking content.",
            "I appreciate the effort you've put into this, but I feel like it's missing some crucial context. Perhaps adding some background information would make it more impactful?",
            "Your unique perspective shines through in this post. It's refreshing to see content that doesn't just follow trends but actually adds value to the conversation.",
            "I'm impressed by the technical skill displayed here, but I'm left wondering about the ethical considerations behind this project. Could you elaborate on that aspect?",
            "This post perfectly captures the zeitgeist of our current moment. It's both a reflection of and a commentary on our society. Brilliantly done!",
            "I've seen similar content before, but your take on it is truly original. You've managed to breathe new life into a familiar concept.",
            "The attention to detail in this post is remarkable. It's clear that you've put a lot of thought and effort into every aspect of it.",
            "This post has sparked an interesting debate in the comments. It's fascinating to see how different people interpret and react to your work."
        ])
        for _ in range(100)
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# %%
import os
from dotenv import load_dotenv
import snowflake.connector

# Load environment variables
load_dotenv()

# Connect to Snowflake
conn = snowflake.connector.connect(
    user=os.getenv('SNOWFLAKE_USERNAME'),
    password=os.getenv('SNOWFLAKE_PASSWORD'),
    account=os.getenv('SNOWFLAKE_ACCOUNT'),
    warehouse=os.getenv('SNOWFLAKE_WAREHOUSE'),
    database=os.getenv('SNOWFLAKE_DATABASE'),
    schema=os.getenv('SNOWFLAKE_SCHEMA')
)

from snowflake.connector.pandas_tools import write_pandas

write_pandas(conn, df, 'instagram_comments', auto_create_table=True)

# %%
import instaloader

# Create an instance of Instaloader
L = instaloader.Instaloader()

# Login (optional, but recommended for private accounts)
L.login('johnapple2928', 'Testing1234!')

# Specify the post you want to scrape
post_shortcode = 'C_6lZpgP7mu'  # Replace with the actual shortcode of the post
post = instaloader.Post.from_shortcode(L.context, post_shortcode)

# Scrape comments
comments = []
for comment in post.get_comments():
    comments.append(comment.text)

print(comments)
# Out:
# ---------------------------------------------------------------------------
# QueryReturnedBadRequestException          Traceback (most recent call last)
# Cell In[12], line 11
#       9 # Specify the post you want to scrape
#      10 post_shortcode = 'C_6lZpgP7mu'  # Replace with the actual shortcode of the post
# ---> 11 post = instaloader.Post.from_shortcode(L.context, post_shortcode)
#      13 # Scrape comments
#      14 comments = []
#
# File ~/.pyenv/versions/3.10.7/envs/abbvie/lib/python3.10/site-packages/instaloader/structures.py:207, in Post.from_shortcode(cls, context, shortcode)
#     205 # pylint:disable=protected-access
#     206 post = cls(context, {'shortcode': shortcode})
# --> 207 post._node = post._full_metadata
#     208 return post
#
# File ~/.pyenv/versions/3.10.7/envs/abbvie/lib/python3.10/site-packages/instaloader/structures.py:335, in Post._full_metadata(self)
#     333 @property
#     334 def _full_metadata(self) -> Dict[str, Any]:
# ...
